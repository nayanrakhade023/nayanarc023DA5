# %%
import pandas as pd

# %%
customer = pd.read_csv ('customer 50.csv')

# %%
customer
# Out:
#              cust_id       customer_name      segment  age        country  \
# 0   cust_id-CG-12520         Claire Gute     Consumer   67  United States
# 1   cust_id-DV-13045     Darrin Van Huff    Corporate   31  United States
# 2   cust_id-SO-20335      Sean O'Donnell     Consumer   65  United States
# 3   cust_id-BH-11710     Brosina Hoffman     Consumer   20  United States
# 4   cust_id-AA-10480        Andrew Allen     Consumer   50  United States
# 5   cust_id-IM-15070        Irene Maddox     Consumer   66  United States
# 6   cust_id-HP-14815       Harold Pawlan  Home Office   20  United States
# 7   cust_id-PK-19075           Pete Kriz     Consumer   46  United States
# 8   cust_id-AG-10270     Alejandro Grove     Consumer   18  United States
# 9   cust_id-ZD-21925  Zuschuss Donatelli     Consumer   66  United States
# 10  cust_id-KB-16585           Ken Black    Corporate   67  United States
# 11  cust_id-SF-20065     Sandra Flanagan     Consumer   41  United States
# ...

# %%
customer.head
# Out:
# <bound method NDFrame.head of              cust_id       customer_name      segment  age        country  \
# 0   cust_id-CG-12520         Claire Gute     Consumer   67  United States
# 1   cust_id-DV-13045     Darrin Van Huff    Corporate   31  United States
# 2   cust_id-SO-20335      Sean O'Donnell     Consumer   65  United States
# 3   cust_id-BH-11710     Brosina Hoffman     Consumer   20  United States
# 4   cust_id-AA-10480        Andrew Allen     Consumer   50  United States
# 5   cust_id-IM-15070        Irene Maddox     Consumer   66  United States
# 6   cust_id-HP-14815       Harold Pawlan  Home Office   20  United States
# 7   cust_id-PK-19075           Pete Kriz     Consumer   46  United States
# 8   cust_id-AG-10270     Alejandro Grove     Consumer   18  United States
# 9   cust_id-ZD-21925  Zuschuss Donatelli     Consumer   66  United States
# 10  cust_id-KB-16585           Ken Black    Corporate   67  United States
# ...

# %%
cdata = pd.read_csv('customer 50.csv',header=0,index_col=0)

# %%
cdata
# Out:
#                        customer_name      segment  age        country  \
# cust_id
# cust_id-CG-12520         Claire Gute     Consumer   67  United States
# cust_id-DV-13045     Darrin Van Huff    Corporate   31  United States
# cust_id-SO-20335      Sean O'Donnell     Consumer   65  United States
# cust_id-BH-11710     Brosina Hoffman     Consumer   20  United States
# cust_id-AA-10480        Andrew Allen     Consumer   50  United States
# cust_id-IM-15070        Irene Maddox     Consumer   66  United States
# cust_id-HP-14815       Harold Pawlan  Home Office   20  United States
# cust_id-PK-19075           Pete Kriz     Consumer   46  United States
# cust_id-AG-10270     Alejandro Grove     Consumer   18  United States
# cust_id-ZD-21925  Zuschuss Donatelli     Consumer   66  United States
# cust_id-KB-16585           Ken Black    Corporate   67  United States
# cust_id-SF-20065     Sandra Flanagan     Consumer   41  United States
# ...

# %%
cdata.describe()
# Out:
#              age   postal_code
# count  49.000000     49.000000
# mean   43.142857  59352.469388
# std    17.621010  27814.913802
# min    18.000000  10009.000000
# 25%    29.000000  35601.000000
# 50%    41.000000  60610.000000
# 75%    63.000000  84084.000000
# max    70.000000  98103.000000

# %%
cdata.iloc[1]
# Out:
# customer_name    Darrin Van Huff
# segment                Corporate
# age                           31
# country            United States
# city                 Los Angeles
# state                 California
# postal_code                90036
# region                      West
# Name: cust_id-DV-13045, dtype: object

# %%
cdata.iloc[1,5]
# Out:
# 'California'

# %%
cdata.iloc[0:5]
# Out:
#                     customer_name    segment  age        country  \
# cust_id
# cust_id-CG-12520      Claire Gute   Consumer   67  United States
# cust_id-DV-13045  Darrin Van Huff  Corporate   31  United States
# cust_id-SO-20335   Sean O'Donnell   Consumer   65  United States
# cust_id-BH-11710  Brosina Hoffman   Consumer   20  United States
# cust_id-AA-10480     Andrew Allen   Consumer   50  United States
#
#                              city           state  postal_code region
# cust_id
# cust_id-CG-12520        Henderson        Kentucky        42420  South
# cust_id-DV-13045      Los Angeles      California        90036   West
# cust_id-SO-20335  Fort Lauderdale         Florida        33311  South
# cust_id-BH-11710      Los Angeles      California        90032   West
# cust_id-AA-10480          Concord  North Carolina        28027  South

# %%
cdata.iloc[10:30]
# Out:
#                       customer_name      segment  age        country  \
# cust_id
# cust_id-KB-16585          Ken Black    Corporate   67  United States
# cust_id-SF-20065    Sandra Flanagan     Consumer   41  United States
# cust_id-EB-13870        Emily Burns     Consumer   34  United States
# cust_id-EH-13945      Eric Hoffmann     Consumer   21  United States
# cust_id-TB-21520    Tracy Blumstein     Consumer   48  United States
# cust_id-MA-17560       Matt Abelman  Home Office   19  United States
# cust_id-GH-14485          Gene Hale    Corporate   28  United States
# cust_id-SN-20710       Steve Nguyen  Home Office   46  United States
# cust_id-LC-16930     Linda Cazamias    Corporate   31  United States
# cust_id-RA-19885       Ruben Ausman    Corporate   51  United States
# cust_id-ES-14080         Erin Smith    Corporate   20  United States
# cust_id-ON-18715      Odella Nelson    Corporate   27  United States
# ...

# %%
sales = pd.read_csv('sales 50.csv')

# %%
sales
# Out:
#     order_line        order_id  order_date   ship_date       ship_mode  \
# 0            1  CA-2016-152156  08-11-2016  11-11-2016    Second Class
# 1            2  CA-2016-152156  08-11-2016  11-11-2016    Second Class
# 2            3  CA-2016-138688  12-06-2016  16-06-2016    Second Class
# 3            4  US-2015-108966  11-10-2015  18-10-2015  Standard Class
# 4            5  US-2015-108966  11-10-2015  18-10-2015  Standard Class
# 5            6  CA-2014-115812  09-06-2014  14-06-2014  Standard Class
# 6            7  CA-2014-115812  09-06-2014  14-06-2014  Standard Class
# 7            8  CA-2014-115812  09-06-2014  14-06-2014  Standard Class
# 8            9  CA-2014-115812  09-06-2014  14-06-2014  Standard Class
# 9           10  CA-2014-115812  09-06-2014  14-06-2014  Standard Class
# 10          11  CA-2014-115812  09-06-2014  14-06-2014  Standard Class
# 11          12  CA-2014-115812  09-06-2014  14-06-2014  Standard Class
# ...

# %%
sales.head
# Out:
# <bound method NDFrame.head of     order_line        order_id  order_date   ship_date       ship_mode  \
# 0            1  CA-2016-152156  08-11-2016  11-11-2016    Second Class
# 1            2  CA-2016-152156  08-11-2016  11-11-2016    Second Class
# 2            3  CA-2016-138688  12-06-2016  16-06-2016    Second Class
# 3            4  US-2015-108966  11-10-2015  18-10-2015  Standard Class
# 4            5  US-2015-108966  11-10-2015  18-10-2015  Standard Class
# 5            6  CA-2014-115812  09-06-2014  14-06-2014  Standard Class
# 6            7  CA-2014-115812  09-06-2014  14-06-2014  Standard Class
# 7            8  CA-2014-115812  09-06-2014  14-06-2014  Standard Class
# 8            9  CA-2014-115812  09-06-2014  14-06-2014  Standard Class
# 9           10  CA-2014-115812  09-06-2014  14-06-2014  Standard Class
# 10          11  CA-2014-115812  09-06-2014  14-06-2014  Standard Class
# 11          12  CA-2014-115812  09-06-2014  14-06-2014  Standard Class
# ...

# %%
sdata = pd.read_csv('sales 50.csv',header=0,index_col=0)

# %%
sdata
# Out:
#                   order_id  order_date   ship_date       ship_mode  \
# order_line
# 1           CA-2016-152156  08-11-2016  11-11-2016    Second Class
# 2           CA-2016-152156  08-11-2016  11-11-2016    Second Class
# 3           CA-2016-138688  12-06-2016  16-06-2016    Second Class
# 4           US-2015-108966  11-10-2015  18-10-2015  Standard Class
# 5           US-2015-108966  11-10-2015  18-10-2015  Standard Class
# 6           CA-2014-115812  09-06-2014  14-06-2014  Standard Class
# 7           CA-2014-115812  09-06-2014  14-06-2014  Standard Class
# 8           CA-2014-115812  09-06-2014  14-06-2014  Standard Class
# 9           CA-2014-115812  09-06-2014  14-06-2014  Standard Class
# 10          CA-2014-115812  09-06-2014  14-06-2014  Standard Class
# 11          CA-2014-115812  09-06-2014  14-06-2014  Standard Class
# 12          CA-2014-115812  09-06-2014  14-06-2014  Standard Class
# 13          CA-2017-114412  15-04-2017  20-04-2017  Standard Class
# ...

# %%
sdata.describe()
# Out:
#              sales   quantity   discount       profit
# count    49.000000  49.000000  49.000000    49.000000
# mean    306.142831   3.877551   0.193265   -21.341914
# std     551.918846   1.975186   0.220070   254.305334
# min       2.544000   2.000000   0.000000 -1665.052200
# 25%      19.460000   2.000000   0.000000     2.482400
# 50%      77.880000   3.000000   0.200000     8.206200
# 75%     261.960000   5.000000   0.200000    16.556400
# max    3083.430000   9.000000   0.800000   240.264900

# %%
sdata.iloc[0]
# Out:
# order_id        CA-2016-152156
# order_date          08-11-2016
# ship_date           11-11-2016
# ship_mode         Second Class
# customer_id           CG-12520
# product_id     FUR-BO-10001798
# sales                   261.96
# quantity                     2
# discount                   0.0
# profit                 41.9136
# Name: 1, dtype: object

# %%
sdata.iloc[0,5]
# Out:
# 'FUR-BO-10001798'

# %%
sdata.iloc[10:20]
# Out:
#                   order_id  order_date   ship_date       ship_mode  \
# order_line
# 11          CA-2014-115812  09-06-2014  14-06-2014  Standard Class
# 12          CA-2014-115812  09-06-2014  14-06-2014  Standard Class
# 13          CA-2017-114412  15-04-2017  20-04-2017  Standard Class
# 14          CA-2016-161389  05-12-2016  10-12-2016  Standard Class
# 15          US-2015-118983  22-11-2015  26-11-2015  Standard Class
# 16          US-2015-118983  22-11-2015  26-11-2015  Standard Class
# 17          CA-2014-105893  11-11-2014  18-11-2014  Standard Class
# 18          CA-2014-167164  13-05-2014  15-05-2014    Second Class
# 19          CA-2014-143336  27-08-2014  01-09-2014    Second Class
# 20          CA-2014-143336  27-08-2014  01-09-2014    Second Class
#
#            customer_id       product_id     sales  quantity  discount  \
# order_line
# 11            BH-11710  FUR-TA-10001539  1706.184         9       0.2
# ...

# %%
sdata.iloc[0:5]
# Out:
#                   order_id  order_date   ship_date       ship_mode  \
# order_line
# 1           CA-2016-152156  08-11-2016  11-11-2016    Second Class
# 2           CA-2016-152156  08-11-2016  11-11-2016    Second Class
# 3           CA-2016-138688  12-06-2016  16-06-2016    Second Class
# 4           US-2015-108966  11-10-2015  18-10-2015  Standard Class
# 5           US-2015-108966  11-10-2015  18-10-2015  Standard Class
#
#            customer_id       product_id     sales  quantity  discount  \
# order_line
# 1             CG-12520  FUR-BO-10001798  261.9600         2      0.00
# 2             CG-12520  FUR-CH-10000454  731.9400         3      0.00
# 3             DV-13045  OFF-LA-10000240   14.6200         2      0.00
# 4             SO-20335  FUR-TA-10000577  957.5775         5      0.45
# 5             SO-20335  OFF-ST-10000760   22.3680         2      0.20
#
#               profit
# order_line
# 1            41.9136
# 2           219.5820
# 3             6.8714
# ...

# %%
product = pd.read_csv('product 50.csv')

# %%
product
# Out:
#          product_id         category sub_category  \
# 0   FUR-BO-10001798        Furniture    Bookcases
# 1   FUR-BO-10001798        Furniture   Bookcases1
# 2   FUR-CH-10000454        Furniture       Chairs
# 3   OFF-LA-10000240  Office Supplies       Labels
# 4   FUR-TA-10000577        Furniture       Tables
# 5   OFF-ST-10000760  Office Supplies      Storage
# 6   FUR-FU-10001487        Furniture  Furnishings
# 7   OFF-AR-10002833  Office Supplies          Art
# 8   TEC-PH-10002275       Technology       Phones
# 9   OFF-BI-10003910  Office Supplies      Binders
# 10  OFF-AP-10002892  Office Supplies   Appliances
# 11  FUR-TA-10001539        Furniture       Tables
# 12  TEC-PH-10002033       Technology       Phones
# 13  OFF-PA-10002365  Office Supplies        Paper
# 14  OFF-BI-10003656  Office Supplies      Binders
# 15  OFF-AP-10002311  Office Supplies   Appliances
# 16  OFF-BI-10000756  Office Supplies      Binders
# 17  OFF-ST-10004186  Office Supplies      Storage
# ...

# %%
product.head
# Out:
# <bound method NDFrame.head of          product_id         category sub_category  \
# 0   FUR-BO-10001798        Furniture    Bookcases
# 1   FUR-BO-10001798        Furniture   Bookcases1
# 2   FUR-CH-10000454        Furniture       Chairs
# 3   OFF-LA-10000240  Office Supplies       Labels
# 4   FUR-TA-10000577        Furniture       Tables
# 5   OFF-ST-10000760  Office Supplies      Storage
# 6   FUR-FU-10001487        Furniture  Furnishings
# 7   OFF-AR-10002833  Office Supplies          Art
# 8   TEC-PH-10002275       Technology       Phones
# 9   OFF-BI-10003910  Office Supplies      Binders
# 10  OFF-AP-10002892  Office Supplies   Appliances
# 11  FUR-TA-10001539        Furniture       Tables
# 12  TEC-PH-10002033       Technology       Phones
# 13  OFF-PA-10002365  Office Supplies        Paper
# 14  OFF-BI-10003656  Office Supplies      Binders
# 15  OFF-AP-10002311  Office Supplies   Appliances
# 16  OFF-BI-10000756  Office Supplies      Binders
# ...

# %%
pdata = pd.read_csv('product 50.csv',header=0,index_col=0)

# %%
pdata
# Out:
#                         category sub_category  \
# product_id
# FUR-BO-10001798        Furniture    Bookcases
# FUR-BO-10001798        Furniture   Bookcases1
# FUR-CH-10000454        Furniture       Chairs
# OFF-LA-10000240  Office Supplies       Labels
# FUR-TA-10000577        Furniture       Tables
# OFF-ST-10000760  Office Supplies      Storage
# FUR-FU-10001487        Furniture  Furnishings
# OFF-AR-10002833  Office Supplies          Art
# TEC-PH-10002275       Technology       Phones
# OFF-BI-10003910  Office Supplies      Binders
# OFF-AP-10002892  Office Supplies   Appliances
# FUR-TA-10001539        Furniture       Tables
# TEC-PH-10002033       Technology       Phones
# OFF-PA-10002365  Office Supplies        Paper
# OFF-BI-10003656  Office Supplies      Binders
# OFF-AP-10002311  Office Supplies   Appliances
# OFF-BI-10000756  Office Supplies      Binders
# OFF-ST-10004186  Office Supplies      Storage
# OFF-ST-10000107  Office Supplies      Storage
# ...

# %%
pdata.describe()
# Out:
#                category sub_category                       product_name
# count                49           49                                 49
# unique                3           14                                 48
# top     Office Supplies      Binders  Bush Somerset Collection Bookcase
# freq                 27            8                                  2

# %%
pdata.iloc[0]
# Out:
# category                                Furniture
# sub_category                            Bookcases
# product_name    Bush Somerset Collection Bookcase
# Name: FUR-BO-10001798, dtype: object

# %%
pdata.iloc[0,2]
# Out:
# 'Bush Somerset Collection Bookcase'

# %%
pdata.iloc[0:7]
# Out:
#                         category sub_category  \
# product_id
# FUR-BO-10001798        Furniture    Bookcases
# FUR-BO-10001798        Furniture   Bookcases1
# FUR-CH-10000454        Furniture       Chairs
# OFF-LA-10000240  Office Supplies       Labels
# FUR-TA-10000577        Furniture       Tables
# OFF-ST-10000760  Office Supplies      Storage
# FUR-FU-10001487        Furniture  Furnishings
#
#                                                       product_name
# product_id
# FUR-BO-10001798                  Bush Somerset Collection Bookcase
# FUR-BO-10001798                  Bush Somerset Collection Bookcase
# FUR-CH-10000454  Hon Deluxe Fabric Upholstered Stacking Chairs ...
# OFF-LA-10000240  Self-Adhesive Address Labels for Typewriters b...
# FUR-TA-10000577      Bretford CR4500 Series Slim Rectangular Table
# OFF-ST-10000760                      Eldon Fold N Roll Cart System
# FUR-FU-10001487  Eldon Expressions Wood and Plastic Desk Access...

# %%
pdata.iloc[15:30]
# Out:
#                         category sub_category  \
# product_id
# OFF-AP-10002311  Office Supplies   Appliances
# OFF-BI-10000756  Office Supplies      Binders
# OFF-ST-10004186  Office Supplies      Storage
# OFF-ST-10000107  Office Supplies      Storage
# OFF-AR-10003056  Office Supplies          Art
# TEC-PH-10001949       Technology       Phones
# OFF-BI-10002215  Office Supplies      Binders
# OFF-AR-10000246  Office Supplies          Art
# OFF-AP-10001492  Office Supplies   Appliances
# FUR-CH-10002774        Furniture       Chairs
# OFF-BI-10001634  Office Supplies      Binders
# TEC-AC-10003027       Technology  Accessories
# FUR-BO-10004834        Furniture    Bookcases
# OFF-BI-10000474  Office Supplies      Binders
# FUR-FU-10004848        Furniture  Furnishings
#
#                                                       product_name
# product_id
# OFF-AP-10002311  Holmes Replacement Filter for HEPA Air Cleaner...
# ...
